# %% [markdown]
# # RAG Pipeline - Data Ingestion to Vector DB pipeline

# %%
import os
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
# !pip install pypdf

# %%
### Read all the pdfs inside the directory
def process_all_pdfs(pdf_directory):
    all_documents = []
    pdf_dir = Path(pdf_directory)

    # find all pdf files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))

    print(f"Found {len(pdf_files)} PDF file to process.")

    for pdf_file in pdf_files:
        print(f"\n Processing {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()

            # Add source information to metadata
            for doc in documents:
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata["file_type"] = 'pdf'
            
            all_documents.extend(documents)
            print(f"Loaded {len(documents)} pages.")
        
        except Exception as e:
            print(f"Error: {e}")

    print(f"\nTotal Documents loaded: {len(all_documents)}")
    return all_documents

all_pdf_documents = process_all_pdfs("data")
# Out:
# Found 3 PDF file to process.
#
#  Processing A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf
# Loaded 13 pages.
#
#  Processing Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf
# Loaded 36 pages.
#
#  Processing Which_kind_of_research_papers_influence_policymaki.pdf
# Loaded 30 pages.
#
# Total Documents loaded: 79

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='A Major Project Progress Report\non Implementing Read/Write Overlay\nFilesystem Support In A Microkernel\nBased Operating System\nRijan Karki      Saurav Khanal      Spandan Guragain      Sudesh Subedi\n1'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 1, 'page_label': '2', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Introduction\nOverlay filesystem support in Redox OS, a microkernel based operating system\nwritten in rust focusing on safety, freedom, stabillity, correctness, and pragmatism. \nWe are implementinig an \n2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Some Uses Of OverlayFS\nContainerization and Virtualization System Installation, Testing and Recovery \n3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 3, 'page_label': '4', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Progress Overview\nThis is preliminary work focused on understanding overlay filesystem\nconcepts and creating a basic proof of concept implementation. The current\ncode serves as a foundation for testing core overlay filesystem mechanics\nbefore attempting integration with Redox OS.\n4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 4, 'page_label': '5', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Acomplishments\n5 \n1\n2\nLearning Phase\nCode Structuring\n3 Testing Setup'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 5, 'page_label': '6', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Learning Phase\n6 \nStudied overlay filesystem concepts and implementation approaches\nGained familiarity with the Redox OS build system\nSet up a basic Rust project structure for development'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 6, 'page_label': '7', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Testing Setup\n7 \nCreated unit tests using temporary directories\nTests cover basic scenarios like reading from lower layer,\nwriting to files, and directory merging\nTests help verify that the overlay concept works in principle'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 7, 'page_label': '8', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Code Structuring\n8 \nConfig struct to hold paths for upper layer, lower layer, and work directory\nFileLayer enum to track whether a file comes from upper layer, lower\nlayer, or was copied\nOverlayFile struct to wrap files with additional metadata\nFileSystem struct as the main coordinator\nCore Data Structures:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 8, 'page_label': '9', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Code Structuring\n9 \nFile opening with layer detection (checks upper layer first,\nthen lower layer)\nSimple read operations from both layers\nBasic write operations with copy on write concept\nFile deletion using whiteout files (files prefixed with .wh.)\nDirectory listing that merges entries from both layers\nBasic Operations:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 9, 'page_label': '10', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Methodology\nPrototype Development Model:\nDevelop a minimal implementation.\n01\nContinuously add features and\nimprove on the previous prototype.\n02\n1 0'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Current Limitations\n1 1 \n1\n2\nNot Yet Integrated\nDelegate Implementation\n3 Missing CLI and Features'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 11, 'page_label': '12', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Project Timeline\n1 2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 12, 'page_label': '13', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Thank you\n1 3'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 0, 'page_label': '1', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='TRIBHUV AN UNIVERSITY\nINSTITUTE OF ENGINEERING\nPURW ANCHAL CAMPUS\nA MINOR PROJECT REPORT ON\nONLYFRIENDS: A SMART PLATFORM FOR CONNECTING\nLIKE-MINDED INDIVIDUALS\nBY\nAMRIT GNA W ALI (PUR078 BCT006)\nANISH DAHAL (PUR078 BCT007)\nKAPIL DEV KUMAR MAHATO (PUR078 BCT041)\nKAUSHALENDRA MAHATO (PUR078 BCT042)\nDEPARTMENT OF ELECTRONICS AND COMPUTER ENGINEERING\nPURW ANCHAL CAMPUS\nDHARAN, NEPAL\nMARCH,2025'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 1, 'page_label': '2', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='COPYRIGHT ©\nThe author has granted permission to the Library of the Department of Electronics\nand Computer Engineering, Purwanchal Campus, Institute of Engineering, to make this\nreport freely available for inspection. Additionally, permission for extensive copying of\nthis project report for scholarly purposes may be granted by the supervising faculty. In\ntheir absence, such permission may be granted by the Head of the Department.\nProper acknowledgment must be given to the author and the Department of Elec-\ntronics and Computer Engineering, Purwanchal Campus, Institute of Engineering, in\nany use of the material contained in this report. Any reproduction, publication, or other\nuse of this report for financial gain is strictly prohibited without prior written permission\nfrom both the author and the Department.\nRequests for permission to copy or use any part of this report should be addressed\nto:\nHead of Department\nDepartment of Electronics and Computer Engineering\nPurwanchal Campus, Institute of Engineering\nDharan, Sunsari, Nepal\ni'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 2, 'page_label': '3', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='DECLARATION\nWe declare that the work hereby submitted for Bachelors of Engineering in Com-\nputer Engineering at Institute of Engineering, Purwanchal Campus entitledONLYFRIENDS:\nA SMART PLATFORM FOR CONNECTING LIKE-MINDED INDIVIDUALSis\nour own work and has not been previously submitted by me at any university for any\nacademic award. We authorize Institute of Engineering, Purwanchal Campus to lend\nthis report to other institution or individuals for the purpose of scholarly research.\nAnish Dahal [PUR078BCT007]\nAmrit Gnawali [PUR078BCT006]\nKaushalendra Mahato [PUR078BCT042]\nKapildev Kumar Mahato [PUR078BCT041]\nMarch, 2025\nii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 3, 'page_label': '4', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='CERTIFICATE OF APPROV AL\nThe undersigned certify that they have read, and recommended to the Institute of\nEngineering for acceptance, a project report entitled ONLYFRIENDS: A SMART\nPLATFORM FOR CONNECTING LIKE-MINDED INDIVIDUALSsubmitted by\nAnish Dahal, Kaushalendra Mahato, Amrit Gnawali and Kapildev Kumar Mahato in\npartial fulfilment of the requirements for the Bachelor’s Degree in Computer Engineer-\ning.\nDeputy Head of Department: Asst. Prof. Pukar Karki\nDepartment of Electronics and Computer Engineering\nInstitute of Engineering, Purwanchal Campus\nDate of Approval: March, 2025\nSupervisor of Project: Asst. Prof. Bishnu Chaudhary\nDepartment of Electronics and Computer Engineering\nInstitute of Engineering, Purwanchal Campus\nDate of Approval: March, 2025\niii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 4, 'page_label': '5', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='ACKNOWLEDGEMENT\nWe express our sincere appreciation to our Suvervisor Asst. Prof. Bishnu Chaud-\nhary, Mr. Pukar Karki - the Deputy Head of the Department, for their invaluable guid-\nance, insightful suggestions, constructive feedback, and continuous support throughout\nthe preparation of this report.\nWe are deeply thankful to the esteemed teachers and faculty members whose valu-\nable feedback, encouragement, and scholarly insights have enriched this report. Their\ndedication to academic excellence and commitment to fostering knowledge have been\na source of inspiration. Their collective guidance has immensely contributed to the\nrefinement and improvement of this report.\nAMRIT GNAW ALI(PUR078 BCT006)\nANISH DAHAL(PUR078 BCT007)\nKAPIL DEV KUMAR MAHATO(PUR078 BCT041)\nKAUSHALENDRA MAHATO(PUR078 BCT042)\niv'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 5, 'page_label': '6', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='ABSTRACT\nThis is a web-based application designed to connect like-minded individuals by\nanalyzing user interests and suggesting potential connections. The platform enables\nusers to discover and engage with people who share similar interests. Users can review\nsuggested connections, send friend requests, and establish meaningful friendships.\nBeyond just making connections, the application provides an interactive chat feature\nthat allows users to engage in conversations with their matched contacts. Additionally,\nusers can create posts in text format to share their thoughts, updates, or ideas with\ntheir friends. Other users can interact by liking these posts, fostering engagement and\ndiscussions within the platform.\nThe primary objective of this project is to help individuals find companionship based\non shared interests, making it easier for them to connect, communicate, and establish\ngenuine relationships. This application is particularly designed for youths who are\nlooking for a fun, engaging, and easy-to-use platform to meet new people. The app\nserves as a tool for social networking and entertainment, allowing users to interact in a\ncomfortable virtual environment where they can vibe, have fun, and form meaningful\nconnections.\nKeywords: Social Networking, Interest-based friends Suggestion, Web-based Ap-\nplication, Cosine Similarity algorithm, Post and Like System, Entertainment-purpose,\nPost and Like system, Profile management, Real-time chat\nv'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 6, 'page_label': '7', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='TABLE OF CONTENTS\nCOPYRIGHT i\nDECLARATION ii\nCERTIFICATE OF APPROV AL iii\nACKNOWLEDGEMENT iv\nABSTRACT v\nLIST OF FIGURES ix\n0.1 JWT token implementation . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.2 cosine Vector visualization . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.3 System architecture diagram . . . . . . . . . . . . . . . . . . . . . . . ix\n0.4 Agile Model . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.5 System Use case diagram . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.6 System E-R diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.7 Class Diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.8 Dashboard . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.9 Suggestion Page . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.10 Chat Page . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\nLIST OF ABBREVIATIONS x\n1 INTRODUCTION 1\nINTRODUCTION 1\n1.1 Background . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1\n1.2 Problem Statement . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1\n1.3 Main Objectives . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1\n1.4 Scope and Application . . . . . . . . . . . . . . . . . . . . . . . . . . 2\n1.5 Feasibility analysis . . . . . . . . . . . . . . . . . . . . . . . . . . . . 2\n1.5.1 Technical Feasibility . . . . . . . . . . . . . . . . . . . . . . . 2\nvi'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 7, 'page_label': '8', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='1.5.2 Economic Feasibility . . . . . . . . . . . . . . . . . . . . . . . 3\n1.6 Performance Scalability . . . . . . . . . . . . . . . . . . . . . . . . . 3\n1.6.1 Performance: . . . . . . . . . . . . . . . . . . . . . . . . . . . 3\n1.6.2 Scalibility: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 4\n2 RELATED THEORY 5\nRELATED THEORY 5\n2.1 Introduction . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 5\n2.2 Social Networking Concepts . . . . . . . . . . . . . . . . . . . . . . . 5\n2.3 Web Development Technologies . . . . . . . . . . . . . . . . . . . . . 5\n2.4 Frontend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 5\n2.4.1 React (Frontend Framework) . . . . . . . . . . . . . . . . . . . 5\n2.5 Backend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 6\n2.5.1 FastAPI (Backend Framework) . . . . . . . . . . . . . . . . . . 6\n2.6 User Authentication and Security . . . . . . . . . . . . . . . . . . . . . 6\n2.6.1 JWT . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 6\n2.7 Chat Functionality . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7\n2.8 Recommendation System . . . . . . . . . . . . . . . . . . . . . . . . . 7\n2.9 Cosine Similarity . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 8\n3 Literature Review 10\nLITERATURE REVIEW 10\n3.1 FastAPI and Modern Web Frameworks . . . . . . . . . . . . . . . . . . 10\n3.2 SQLAlchemy for Database Management . . . . . . . . . . . . . . . . . 10\n3.3 React + Vite for Frontend Development . . . . . . . . . . . . . . . . . 10\n3.4 Firebase for Real-Time Communication . . . . . . . . . . . . . . . . . 10\n3.5 Cosine Similarity and Interest Matching . . . . . . . . . . . . . . . . . 11\n4 METHODOLOGY 12\nvii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 8, 'page_label': '9', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='METHODOLOGY 12\n4.1 Overview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.2 Requirements Analysis . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.3 System Design . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.4 Frontend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.5 Backend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 13\n4.6 Implementing Real-time chat . . . . . . . . . . . . . . . . . . . . . . . 13\n4.7 Profile Matching . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13\n4.8 Software Development Model . . . . . . . . . . . . . . . . . . . . . . 14\n5 UML Diagrams 16\n5.1 System Use Case Diagram . . . . . . . . . . . . . . . . . . . . . . . . 17\n5.2 Entity-Relationship (E-R) diagram . . . . . . . . . . . . . . . . . . . . 18\n5.3 Class diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 19\n6 RESULT AND DISCUSSION 20\nRESULT AND DISCUSSION 20\n6.1 Result: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 20\n7 CONCLUSION AND LIMITATION 22\nCONCLUSION AND LIMITATION 22\n7.1 Conclusion: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 22\n7.2 Limitations . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 22\nREFERENCES 24\nviii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 9, 'page_label': '10', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='List of Figures\n0.1 JWT token implementation\n0.2 cosine Vector visualization\n0.3 System architecture diagram\n0.4 Agile Model\n0.5 System Use case diagram\n0.6 System E-R diagram\n0.7 Class Diagram\n0.8 Dashboard\n0.9 Suggestion Page\n0.10 Chat Page\nix'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 10, 'page_label': '11', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='LIST OF ABBREVIATIONS\nAPI : Application Programming Interface\nAWS : Amazon Web Service\nColab : Colaboratory\nJWT : JSON Web Token\nJSON : Javascript Object Notation\nNLP : Natural Language Processing\nOAuth2 : Open Authorization 2.0\nSPA : single Page Application\nUI : User Interface\nx'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 11, 'page_label': '12', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='CHAPTER 1\nINTRODUCTION\n1.1 Background\nIn today’s digital age, social connectivity has become a significant aspect of every-\nday life. However, traditional social media platforms often focus on broad connections,\nleaving a gap for users seeking meaningful interactions with like-minded individuals.\nRecognizing this need, OnlyFriend is designed as a web-based application to bridge this\ngap. It aims to create an interactive environment where users can register, manage their\nprofiles, and connect with others based on their common interests. Unlike conventional\nsocial media, OnlyFriends emphasizes meaningful conversations and topic-based inter-\nactions. It integrates essential features such as real-time chat, user authentication, and\nprofile management to ensure a seamless and user-friendly experience. The platform\naspires to serve as a hub for entertainment and engagement, particularly for the youth,\nfostering friendships that transcend geographical boundaries.\n1.2 Problem Statement\nCurrent social media platforms prioritize network expansion over fostering mean-\ningful connections, often resulting in superficial interactions. Users find it difficult\nto connect with like-minded individuals due to the absence of an efficient interest-\nbased matching system. Additionally, many platforms have complex interfaces and\noverwhelming features, making it hard for users to focus on building genuine relation-\nships. OnlyFriends aims to bridge this gap by providing a user-friendly, interest-driven\nsocial platform where users can easily discover and connect with individuals who share\nsimilar hobbies. By integrating features like profile matching, real-time chat, and user-\ngenerated content (posts likes), the platform enhances engagement and encourages au-\nthentic social interactions, making online friendships more meaningful and enjoyable\n1.3 Main Objectives\n1. To develop a platform that connects users based on shared interests and hobbies,\nfostering meaningful virtual friendships.\n2. To provide features like real-time chat, content posting, and liking posts to en-\ncourage engagement.\n3. To design an intuitive and accessible interface for seamless navigation and inter-\naction.\n1'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 12, 'page_label': '13', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='1.4 Scope and Application\nThe scope and application of this project are as follows:\n• User Registration and Profile Management: The platform allows users to cre-\nate, update, and manage their profiles, ensuring personalized interactions.\n• Interest-Based Matching: Users are connected based on shared interests facili-\ntating meaningful interactions and friendships.\n• Real-Time Communication: The application integrates real-time chat function-\nality to facilitate communication between connected users.\n• User-Friendly Interface: The platform ensures an intuitive, easy-to-use inter-\nface, making it accessible to a wide range of users, especially the youth.\n• Security and Privacy: The platform guarantees data security and user privacy,\nensuring safe interactions and profile management.\n1.5 Feasibility analysis\nConducting a feasibility analysis is a critical step in assessing the viability of project,\nwherein the potential success is evaluated through an examination of economic, tech-\nnical, and operational factors. In this particular analysis, we will assess the feasibility\nof creating ONLYFRIENDS: A SMART PLATFORM FOR CONNECTING LIKE-\nMINDED INDIVIDUALS\n1.5.1 Technical Feasibility\nThe technical feasibility of the **OnlyFriends** platform is achievable through the\nintegration of several key technologies:\n• The platform is built using modern web technologies like React for the frontend\nand Python based framework FastAPI for the backend, ensuring smooth com-\nmunication and responsiveness.\n• PostgreSQL has been utilized for user data storage, ensuring scalability, data\nintegrity, and secure user information management.\n• Firebase is implemented to ensure real-time communication between users, al-\nlowing them to interact instantly.\n• Secure user authentication will be implemented through JWT (JSON Web To-\nkens), ensuring secure login and data protection.\n• The platform has used the Cosine Similarity algorithm to match users based\n2'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 13, 'page_label': '14', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='on their shared interests. By calculating the similarity between users’ profiles\n(which include interests, the system will suggest users with the most similar in-\nterests(greater than 10 percent), enhancing the likelihood of meaningful connec-\ntions.\n• The platform has been designed with scalability in mind, ensuring that it can\nhandle increasing numbers of users without compromising performance.\n1.5.2 Economic Feasibility\nThe economic feasibility of the **OnlyFriends** platform evaluates the costs, fi-\nnancial benefits, and overall viability of the project. By analyzing initial investment,\noperational costs, and potential revenue sources, we assess the platform’s sustainability\nand profitability.\n• Initial Investment: Development costs include web development tools, devel-\noper hiring, and infrastructure setup, which can be minimized by using open-\nsource technologies like React, FastAPI, and PostgreSQL.\n• Operational Costs: Ongoing expenses include server hosting, maintenance, and\ndata storage. Cloud services like AWS and Firebase offer cost-effective solutions\nto scale the platform.\n• Revenue Streams: The platform can generate revenue through:\n– Premium Memberships: Offering additional features for a subscription\nfee.\n– Advertisements: Generating revenue through non-intrusive ads.\n• Market Demand: With growing demand for personalized online interactions,\nthe platform can tap into an underserved market, particularly among youth and\nhobbyists.\n• Long-Term Sustainability: The low cost of cloud-based services, combined\nwith recurring revenue from premium memberships and in-app purchases, en-\nsures the platform’s long-term economic viability.\n1.6 Performance Scalability\n1.6.1 Performance:\nThe OnlyFriends platform is optimized for high performance, ensuring seamless\nuser interactions and real-time communication. The backend, built using FastAPI,\n3'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 14, 'page_label': '15', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='leverages asynchronous processing to handle multiple requests efficiently. PostgreSQL\nensures fast query execution and optimized data retrieval, while Firebase enables low-\nlatency real-time chat. For interest-based profile matching, the Cosine Similarity algo-\nrithm efficiently processes large datasets by representing user interests as vectors and\ncomputing similarity scores, ensuring quick and accurate user recommendations.\n1.6.2 Scalibility:\nThe OnlyFriends platform is designed with scalability in mind, ensuring that it can\nhandle a growing user base without performance degradation. The microservices-based\nbackend, developed with FastAPI, allows independent scaling of different components\nsuch as authentication, chat, and profile matching. PostgreSQL is optimized for large-\nscale data handling, while Firebase provides scalable real-time communication. The\nCosine Similarity algorithm is implemented efficiently to handle increasing data by\nusing vectorized computations and indexing techniques.\n4'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 15, 'page_label': '16', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='CHAPTER 2\nRELATED THEORY\n2.1 Introduction\nThe development of OnlyFriends is based on several fundamental theories and tech-\nnological concepts that ensure efficient functionality, security, and user experience. This\nchapter explores the key theories and technologies involved in building the platform.\n2.2 Social Networking Concepts\nSocial networking revolves around forming and maintaining relationships through\ndigital platforms. OnlyFriends follows the principles of online community building,\nwhere users interact based on shared interests rather than random social connections.\nThe platform enhances engagement by promoting meaningful discussions and fostering\nreal connections.\n2.3 Web Development Technologies\nWeb development is the process of building and maintaining websites and web ap-\nplications. It involves various technologies and practices that help create dynamic, inter-\nactive, and responsive websites or applications. In modern web development, the focus\nis on delivering seamless user experiences, high-performance systems, and scalable ap-\nplications. For platforms like OnlyFriends, which aim to provide real-time interactions\nand dynamic content, the right combination of technologies is crucial\n2.4 Frontend Development\nThe frontend refers to the user interface (UI) and everything the user interacts with in\na web application. It includes the layout, design, and structure of a web page. Frontend\ntechnologies focus on creating a seamless, responsive, and engaging user experience.\n2.4.1 React (Frontend Framework)\nReact is a JavaScript library for building user interfaces, primarily single-page appli-\ncations (SPAs), where you need a fast, dynamic, and responsive interface. Component-\nBased Architecture: React uses components that can be reused across the application,\nimproving the maintainability and scalability of the application. State Management:\nReact helps manage the state (data) across different components, ensuring the UI is\n5'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 16, 'page_label': '17', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='updated in response to user actions or backend changes. Libraries like Redux are of-\nten used with React for more advanced state management. Virtual DOM: React uses a\nvirtual DOM (Document Object Model) to efficiently update the actual DOM by com-\nparing the current and previous state of the UI, improving performance.\n2.5 Backend Development\nThe backend of a web application involves the server, database, and application\nlogic that handle the requests made by users on the frontend. It processes the data and\nsends the appropriate responses to the frontend for rendering.\n2.5.1 FastAPI (Backend Framework)\nFastAPI is a modern web framework built for building APIs with Python, designed\nfor high performance and ease of use. It is ideal for building RESTful APIs and is\nused extensively in web applications for user authentication, data handling, and real-\ntime interactions. Key Features: Automatic Validation: FastAPI automatically validates\nrequest data based on Python type annotations. Asynchronous Support: Built-in support\nfor asynchronous programming using Python’s async/await syntax, making it suitable\nfor handling a large number of simultaneous connections (important for real-time chat\nfeatures). Fast Performance: One of the fastest Python frameworks due to its use of\nStarlette for asynchronous HTTP handling and Pydantic for data validation\n2.6 User Authentication and Security\nSecurity is crucial in any web application, especially for social platforms dealing\nwith personal information. Modern web applications rely on secure authentication\nmechanisms to protect user data and ensure only authorized access.\n2.6.1 JWT\nJWT is a compact, URL-safe token format used for securely transmitting informa-\ntion between parties as a JSON object. It is commonly used for authentication and\nauthorization in web applications.\nJWT Authentication Flow:\nThe client sends a login request with credentials.\nThe server generates a JWT token and sends it back to the client.\nThe client stores the token (typically in local storage) and includes it in the header\n6'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 17, 'page_label': '18', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='of subsequent API requests to authenticate the user\nFigure 2.1: JWT token implementation\n2.7 Chat Functionality\nFirebase is a platform by Google that offers various services, including real-time\ndatabases, authentication, cloud storage, and more. For real-time chat in OnlyFriends,\nFirebase’s Cloud Firestore can be used for storing and synchronizing chat messages in\nreal-time.\nKey Features:\nReal-Time Database: Firebase’s real-time database ensures that data is synchronized\ninstantly across all connected clients. When a user sends a message, it is immediately\nreflected on all other clients, making it an ideal solution for chat systems.\nAuthentication: Firebase provides secure and streamlined authentication methods,\nincluding email/password login and third-party integrations (e.g., Google, Facebook).\nThis ensures secure access to the platform and allows users to log in easily.\n2.8 Recommendation System\nRecommendation systems use vector similarity to suggest connections in OnlyFriends.\nBy ranking users based on cosine similarity scores, the system prioritizes highly com-\npatible matches.\nTypes of Recommendation Approaches:\n7'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 18, 'page_label': '19', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='Content-Based Filtering: Uses user profile data (e.g., interests) for personalized\nrecommendations.\nCollaborative Filtering: Leverages behavior patterns from multiple users to suggest\nconnections.\nHybrid Approach: Combines content-based and collaborative filtering for improved\naccuracy.\n2.9 Cosine Similarity\nCosine Similarity is a metric used to measure how similar two non-zero vectors are\nby calculating the cosine of the angle between them in a multi-dimensional space. It is\ncommonly used in text analysis, recommendation systems, and profile matching where\ndata is represented as vectors. The closer the angle is to 0 degrees, the more similar\nthe vectors are, with a cosine similarity of 1 indicating identical vectors and 0 meaning\ncompletely dissimilar.\nMathematical Formula\nCosine similarity between two vectors A and B is given by:\ncos(θ) =∥A∥∥B∥\nA ·B\nA ·B\nis the dot product of vector A and vector B\n∥A∥ and ∥B∥ are the Euclidean norms (magnitudes) of A and B.\nInterpretation of Cosine Similarity Values:\n• 1 (or close to 1): Highly similar vectors (strong correlation).\n• 0: No similarity (orthogonal vectors).\n• -1 (or close to -1): Opposite vectors (negative correlation, rarely used in recom-\nmendation systems).\nApplication in Profile Matching\nIn OnlyFriends, user interests are stored as text data. To match users based on their\ninterests, the following steps are followed:\nConvert interests into numerical vectors using TF-IDF (explained below).\nCompute the cosine similarity between each pair of user vectors.\n8'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 19, 'page_label': '20', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='Figure 2.2: Cosine vector visualization\nRank users based on similarity scores, suggesting those with high scores.\n9'),
# ...
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 23, 'page_label': '24', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='24 \n \nRobinson-García, N., van Leeuwen, T. N., & Ràfols, I. (2018) ‘Using altmetrics for contextualised \nmapping of societal impact: From hits to networks ’, Science and Public Policy, 45 /6: 815–826. \nhttps://doi.org/10.1093/scipol/scy024 \nREF (2021) United Kingdom Research Excellence Framework (REF) to evaluate research quality \nin higher education institutions. Retrieved November 6, 2023, from https://www.ref.ac.uk/ \nShema, H., Bar -Ilan, J., & Thelwall, M. (2015) ‘ How is research blogged? A content analysis \napproach’, Journal of the Association for Information Science and Technology, 66/6: 1136–1149. \nhttps://doi.org/10.1002/asi.23239 \nSpaapen, J., & Van Drooge, L. (2011) ‘Introducing ‘productive interactions’ in social impact \nassessment’, Research Evaluation, 20/ 3: 211–218. \nhttps://doi.org/10.3152/095820211X12941371876742 \nSyn, S. Y ., & Oh, S. (2015) ‘Why do social network site users share information on Facebook and \nTwitter?’, Journal of Information Science , 41/ 5: 553–569. \nhttps://doi.org/10.1177/0165551515585717 \nSzomszor, M., & Adie, E. (2022) ‘Overton: A bibliometric database of policy document citations’, \nQuantitative Science Studies, 3/3: 624–650. https://doi.org/10.1162/qss_a_00204 \nTattersall, A., & Carroll, C. (2018) ‘ What can Altmetric. com tell us about policy citations of \nresearch? An analysis of Altmetric.com data for research articles from the University of \nSheffield’, Frontiers in R esearch Metrics and Analytics, 2 : 9. \nhttps://doi.org/10.3389/frma.2017.00009 \nVeletsianos, G. (2012) ‘Higher education scholars’ participation and practices on Twitter ’, \nJournal of Computer Assisted Learning, 28 /4: 336–349. https://doi.org/10.1111/j.1365-\n2729.2011.00449.x \nWillis, C. D., Riley, B., Stockton, L., Viehbeck, S., Wutzke, S., & Frank, J. (2017) ‘Evaluating \nthe impact of applied prevention research centres: Results from a modified Delphi approach ’, \nResearch Evaluation, 26/2: 78–90. https://doi.org/10.1093/reseval/rvx010 \nWilsdon, J., Allen, L., Belfiore, E., Campbell, P., Curry, S., Hill, S., et al. (2015) The metric Tide: \nReport of the independent review of the role of metrics in research assessment and management. \nBristol: Higher Education Funding Council for England (HEFCE).  \nhttps://doi.org10.13140/RG.2.1.4929.1363 \nWouters, P ., Zahedi, Z., & Costas, R. (2019) ‘Social media metrics for new research evaluation’. \nIn: Glänzel, W., Moed, H.F., Schmoch, U., Thelwall, M. (eds) Springer Handbook of Science and \nTechnology Indicators. Springer Handbooks. Springer, Cham. https://doi.org/10.1007/978-3-030-\n02511-3_26 \nYin, Y ., Gao, J., Jones, B. F., & Wang, D. (2021) ‘Coevolution of policy and science during the \npandemic’, Science, 371/6525: 128–130. https://doi.org/10.1126/science.abe3084 \nYu, H., Murat, B., Li, J., & Li, L. (2023) ‘How can policy document mentions to scholarly papers \nbe interpreted? An analysis of the underlying mentioning process ’, Scientometrics, 128: 6247–\n6266. https://doi.org/10.1007/s11192-023-04826-y \nYu, H., Xu, S., Xiao, T., Hemminger, B. M., & Yang, S. (2017) ‘Global science discussed in local \naltmetrics: Weibo and its comparison with Twitter ’, Journal of Informetrics , 11 /2: 466–482. \nhttps://doi.org/10 ...
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 24, 'page_label': '25', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='25 \n \nTable 1. Frequencies for qualitative data (N=149,557) \nVariables Categories Num articles % \nJournal expert rating A* (higher) 24,849 16.6  \nA 43,560 29.1  \nB 48,762 32.6  \nC (lower) 32,386 21.7 \nJournal best quartile SJR Q1 (higher) 119,718 80.0  \nQ2 22,387 15.0  \nQ3 6,046 4.0  \nQ4 (lower) 1,406 1.0 \nOA status No 92,262 61.7  \nYes 57,295 38.3 \nOA type closed 92,261 61.7 \n hybrid 20,938 14.0  \ngreen 22,202 14.8  \ngold 3,903 2.6  \nbronze 10,253 6.9 \nFunding No 117,764 78.7 \n Yes 31,793 21.3 \nPublication year 2014 12,565 8.4  \n2015 12,064 8.1  \n2016 20,959 14.0  \n2017 14,454 9.7  \n2018 14,236 9.5  \n2019 14,421 9.6  \n2020 15,870 10.6  \n2021 16,018 10.7  \n2022 15,146 10.1 \n  2023 13,824 9.2'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 25, 'page_label': '26', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='26 \n \nTable 2. Descriptive statistics for quantitative data (N=149,557) \nVariables Min Max Mean SD \nPolicy citations 0 119 0.209 1.142 \nJournal prestige score SJR 0.101 8.346 1.233 1.237 \nJournal impact (cites per doc 3 years) 0.053 15.297 3.168 2.331 \nNews mentions 0 386 0.545 3.858 \nBlog mentions 0 122 0.212 0.820 \nPatent citations 0 33 0.002 0.109 \nX mentions 0 16316 11.971 77.324 \nFacebook mentions 0 133 0.139 0.672 \nWikipedia mentions 0 47 0.156 0.840 \nVideo mentions 0 12 0.002 0.065 \nMendeley readers 0 9939 37.615 78.733 \nScientiﬁc citations 0 4669 18.333 58.373'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 26, 'page_label': '27', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='27 \n \nTable 3. ANOVA for log Policy citations \nSource Coef. Stand. \nerror t Pr > |t| \nLower \nlimit \n(95%) \nUpper \nlimit \n(95%) \np-\nvalues \ncodes \nInterception -0.029 0.004 -7.212 <0.0001 -0.036 -0.021 *** \nJournal expert rating-A* 0.034 0.001 27.066 <0.0001 0.032 0.037 *** \nJournal expert rating-A 0.013 0.001 11.289 <0.0001 0.010 0.015 *** \nJournal expert rating-B 0.004 0.001 3.442 0.001 0.002 0.006 *** \nJournal expert rating-C 0.000 0.000      \nJournal best quartile SJR-Q1 0.022 0.004 5.877 <0.0001 0.015 0.030 *** \nJournal best quartile SJR-Q2 0.016 0.004 4.241 <0.0001 0.009 0.024 *** \nJournal best quartile SJR-Q3 0.009 0.004 2.216 0.027 0.001 0.017 * \nJournal best quartile SJR-Q4 0.000 0.000      \nOA type-hybrid 0.040 0.001 34.992 <0.0001 0.038 0.043 *** \nOA type-green 0.018 0.001 17.041 <0.0001 0.016 0.020 *** \nOA type-gold 0.043 0.002 18.423 <0.0001 0.039 0.048 *** \nOA type-bronze 0.012 0.001 8.184 <0.0001 0.009 0.015 *** \nOA type-closed 0.000 0.000      \nFunding-No -0.022 0.001 -24.512 <0.0001 -0.024 -0.021 *** \nFunding-Yes 0.000 0.000      \nPublication year-2014 0.083 0.002 47.309 <0.0001 0.080 0.087 *** \nPublication year-2015 0.072 0.002 40.585 <0.0001 0.068 0.075 *** \nPublication year-2016 0.077 0.002 48.751 <0.0001 0.073 0.080 *** \nPublication year-2017 0.064 0.002 38.108 <0.0001 0.061 0.068 *** \nPublication year-2018 0.060 0.002 35.629 <0.0001 0.057 0.064 *** \nPublication year-2019 0.047 0.002 28.271 <0.0001 0.044 0.051 *** \nPublication year-2020 0.037 0.002 22.607 <0.0001 0.034 0.040 *** \nPublication year-2021 0.026 0.002 15.931 <0.0001 0.023 0.029 *** \nPublication year-2022 0.012 0.002 7.332 <0.0001 0.009 0.015 *** \nPublication year-2023 0.000 0.000      \nSigniﬁcation codes: *** very highly signiﬁcant; ** highly signiﬁcant; * signiﬁcant; 0 < *** < 0.001 \n< ** < 0.01 < * < 0.05'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 27, 'page_label': '28', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='28 \n \nTable 4. Correlations \n  \nJournal prestige score \nSJR \nJournal impact (cites \nper doc 3 years) \nArticle age (years) \nlog News mentions \nlog Blog mentions \nlog Patent citations \nlog X mentions \nlog Facebook \nmentions \nlog Wikipedia \nmentions \nlog Video mentions \nlog Mendeley readers \nlog Scientific citations \nlog Policy citations \nJournal prestige score SJR 1 0.77 0.08 0.10 0.18 0.02 0.15 0.00 0.09 0.01 0.23 0.27 0.14 \nJournal impact (cites per doc 3 years) 0.77 1 0.02 0.09 0.17 0.02 0.13 0.00 0.02 0.02 0.41 0.36 0.20 \nArticle age (years) 0.08 0.02 1 0.01 0.02 0.01 -0.29 0.13 0.09 0.00 0.30 0.39 0.15 \nlog News mentions 0.10 0.09 0.01 1 0.38 0.01 0.24 0.09 0.13 0.09 0.20 0.23 0.15 \nlog Blog mentions 0.18 0.17 0.02 0.38 1 0.01 0.24 0.10 0.10 0.08 0.22 0.25 0.16 \nlog Patent citations 0.02 0.02 0.01 0.01 0.01 1 -0.01 0.00 0.00 0.01 0.02 0.02 0.03 \nlog X mentions 0.15 0.13 -0.29 0.24 0.24 -0.01 1 0.14 0.04 0.05 0.20 0.16 0.05 \nlog Facebook mentions 0.00 0.00 0.13 0.09 0.10 0.00 0.14 1 0.03 0.04 0.10 0.11 0.06 \nlog Wikipedia mentions 0.09 0.02 0.09 0.13 0.10 0.00 0.04 0.03 1 0.04 0.07 0.12 0.06 \nlog Video mentions 0.01 0.02 0.00 0.09 0.08 0.01 0.05 0.04 0.04 1 0.04 0.04 0.03 \nlog Mendeley readers 0.23 0.41 0.30 0.20 0.22 0.02 0.20 0.10 0.07 0.04 1 0.81 0.34 \nlog Scientific citations 0.27 0.36 0.39 0.23 0.25 0.02 0.16 0.11 0.12 0.04 0.81 1 0.37 \nlog Policy citations 0.14 0.20 0.15 0.15 0.16 0.03 0.05 0.06 0.06 0.03 0.34 0.37 1 \nNote: The log refers to the natural logarithm in base e of the variable shifted by one unit.'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 28, 'page_label': '29', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='29 \n \nTable 5. Analysis of variance (log Policy citations) \nSource GL Sum of \nsquares \nSum of \nsquares \nF Pr > F \nModel  19 475.868 25.046 1471.214 <0.0001 \nError 149537 2545.692 0.017 \n  \nTotal corrected 149556 3021.561 \n   \nNote: Calculated against the model Y=Mean(Y). Adjusted R² = 0.157.'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 29, 'page_label': '30', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='30 \n \nTable 6. Model parameters (log Policy citations) \nSource Coef. Stand. \nerror t Pr > |t| \nLower \nlimit \n(95%) \nUpper \nlimit \n(95%) \np-\nvalues \ncodes \nStand. \ncoef. \nJournal level metrics         \nJournal expert rating (higher better) -0.002 0.000 -4.387 <0.0001 -0.003 -0.001 *** -0.014 \nJournal prestige score SJR -0.002 0.000 -4.252 <0.0001 -0.003 -0.001 *** -0.018 \nJournal best quartile SJR (top better) -0.007 0.001 -10.706 <0.0001 -0.008 -0.006 *** -0.028 \nJournal impact score (cites per doc 3 years) 0.005 0.000 20.452 <0.0001 0.005 0.006 *** 0.089 \nArticle attributes         \nArticle age (years) 0.001 0.000 9.555 <0.0001 0.001 0.002 *** 0.029 \nFunding (Yes=1, No=0) 0.002 0.001 2.057 0.040 0.000 0.004 * 0.005 \nOA (relative to closed)         \n     OA hybrid 0.020 0.001 18.155 <0.0001 0.018 0.022 *** 0.049 \n     OA green 0.001 0.001 1.115 0.265 -0.001 0.003 ° 0.003 \n     OA gold 0.011 0.002 4.863 <0.0001 0.006 0.015 *** 0.012 \n     OA bronze 0.006 0.001 4.623 <0.0001 0.004 0.009 *** 0.011 \nArticle level metrics         \nlog News mentions 0.038 0.002 21.625 <0.0001 0.034 0.041 *** 0.057 \nlog Blog mentions 0.055 0.003 20.321 <0.0001 0.050 0.061 *** 0.054 \nlog Patent citations 0.227 0.025 9.196 <0.0001 0.179 0.275 *** 0.022 \nlog X mentions -0.010 0.001 -14.248 <0.0001 -0.012 -0.009 *** -0.040 \nlog Facebook mentions 0.012 0.003 3.865 <0.0000 0.006 0.018 *** 0.009 \nlog Wikipedia mentions 0.008 0.003 2.791 0.005 0.002 0.013 ** 0.007 \nlog Video mentions 0.036 0.022 1.641 0.101 -0.007 0.079 ° 0.004 \nlog Mendeley readers 0.020 0.001 19.412 <0.0001 0.018 0.022 *** 0.086 \nlog Scientific citations 0.057 0.001 56.597 <0.0001 0.055 0.059 *** 0.247 \nInterception -0.058 0.002 -32.023 <0.0001 -0.062 -0.055 *** - \nSigniﬁcation codes: *** very highly signiﬁcant; ** highly signiﬁcant; * signiﬁcant; . marginally \nsigniﬁcant; ° not signiﬁcant; 0 < *** < 0.001 < ** < 0.01 < * < 0.05 < . < 0.1 < ° < 1. The log refers \nto the natural logarithm in base e of the variable shifted by one unit.')]

# %% [markdown]
# ### Text splitting- get into chunks

# %%
def split_documents(documents, chunk_size = 1000, chunk_overlap = 200):
    """Splits document into smaller chunk for better RAG performance"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap,
        length_function = len,
        separators=["\n\n", "\n", " ", ""]
    )
    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")

    # show example of a chunk
    if split_docs:
        print(f"\nExample chunk: ")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks = split_documents(all_pdf_documents)
chunks
# Out:
# Split 79 documents into 179 chunks
#
# Example chunk:
# Content: A Major Project Progress Report
# on Implementing Read/Write Overlay
# Filesystem Support In A Microkernel
# Based Operating System
# Rijan Karki      Saurav Khanal      Spandan Guragain      Sudesh Subedi
# 1...
# Metadata: {'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='A Major Project Progress Report\non Implementing Read/Write Overlay\nFilesystem Support In A Microkernel\nBased Operating System\nRijan Karki      Saurav Khanal      Spandan Guragain      Sudesh Subedi\n1'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 1, 'page_label': '2', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Introduction\nOverlay filesystem support in Redox OS, a microkernel based operating system\nwritten in rust focusing on safety, freedom, stabillity, correctness, and pragmatism. \nWe are implementinig an \n2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Some Uses Of OverlayFS\nContainerization and Virtualization System Installation, Testing and Recovery \n3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 3, 'page_label': '4', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Progress Overview\nThis is preliminary work focused on understanding overlay filesystem\nconcepts and creating a basic proof of concept implementation. The current\ncode serves as a foundation for testing core overlay filesystem mechanics\nbefore attempting integration with Redox OS.\n4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 4, 'page_label': '5', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Acomplishments\n5 \n1\n2\nLearning Phase\nCode Structuring\n3 Testing Setup'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 5, 'page_label': '6', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Learning Phase\n6 \nStudied overlay filesystem concepts and implementation approaches\nGained familiarity with the Redox OS build system\nSet up a basic Rust project structure for development'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 6, 'page_label': '7', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Testing Setup\n7 \nCreated unit tests using temporary directories\nTests cover basic scenarios like reading from lower layer,\nwriting to files, and directory merging\nTests help verify that the overlay concept works in principle'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 7, 'page_label': '8', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Code Structuring\n8 \nConfig struct to hold paths for upper layer, lower layer, and work directory\nFileLayer enum to track whether a file comes from upper layer, lower\nlayer, or was copied\nOverlayFile struct to wrap files with additional metadata\nFileSystem struct as the main coordinator\nCore Data Structures:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 8, 'page_label': '9', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Code Structuring\n9 \nFile opening with layer detection (checks upper layer first,\nthen lower layer)\nSimple read operations from both layers\nBasic write operations with copy on write concept\nFile deletion using whiteout files (files prefixed with .wh.)\nDirectory listing that merges entries from both layers\nBasic Operations:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 9, 'page_label': '10', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Methodology\nPrototype Development Model:\nDevelop a minimal implementation.\n01\nContinuously add features and\nimprove on the previous prototype.\n02\n1 0'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Current Limitations\n1 1 \n1\n2\nNot Yet Integrated\nDelegate Implementation\n3 Missing CLI and Features'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 11, 'page_label': '12', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Project Timeline\n1 2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-08-12T04:37:00+00:00', 'title': 'A Major Project Progress Report on Implementing Read/Write Overlay Filesystem for a Microkernel Based Operating System', 'moddate': '2025-08-12T04:36:59+00:00', 'keywords': 'DAGvvONU8lA,BAFjjl8uqmo,0', 'author': 'Spandan Guragain', 'source': 'data\\pdfs\\A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'total_pages': 13, 'page': 12, 'page_label': '13', 'source_file': 'A Major Project Progress Report on Implementing ReadWrite Overlay Filesystem for a Microkernel Based Operating System.pdf', 'file_type': 'pdf'}, page_content='Thank you\n1 3'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 0, 'page_label': '1', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='TRIBHUV AN UNIVERSITY\nINSTITUTE OF ENGINEERING\nPURW ANCHAL CAMPUS\nA MINOR PROJECT REPORT ON\nONLYFRIENDS: A SMART PLATFORM FOR CONNECTING\nLIKE-MINDED INDIVIDUALS\nBY\nAMRIT GNA W ALI (PUR078 BCT006)\nANISH DAHAL (PUR078 BCT007)\nKAPIL DEV KUMAR MAHATO (PUR078 BCT041)\nKAUSHALENDRA MAHATO (PUR078 BCT042)\nDEPARTMENT OF ELECTRONICS AND COMPUTER ENGINEERING\nPURW ANCHAL CAMPUS\nDHARAN, NEPAL\nMARCH,2025'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 1, 'page_label': '2', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='COPYRIGHT ©\nThe author has granted permission to the Library of the Department of Electronics\nand Computer Engineering, Purwanchal Campus, Institute of Engineering, to make this\nreport freely available for inspection. Additionally, permission for extensive copying of\nthis project report for scholarly purposes may be granted by the supervising faculty. In\ntheir absence, such permission may be granted by the Head of the Department.\nProper acknowledgment must be given to the author and the Department of Elec-\ntronics and Computer Engineering, Purwanchal Campus, Institute of Engineering, in\nany use of the material contained in this report. Any reproduction, publication, or other\nuse of this report for financial gain is strictly prohibited without prior written permission\nfrom both the author and the Department.\nRequests for permission to copy or use any part of this report should be addressed\nto:\nHead of Department\nDepartment of Electronics and Computer Engineering'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 1, 'page_label': '2', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='from both the author and the Department.\nRequests for permission to copy or use any part of this report should be addressed\nto:\nHead of Department\nDepartment of Electronics and Computer Engineering\nPurwanchal Campus, Institute of Engineering\nDharan, Sunsari, Nepal\ni'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 2, 'page_label': '3', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='DECLARATION\nWe declare that the work hereby submitted for Bachelors of Engineering in Com-\nputer Engineering at Institute of Engineering, Purwanchal Campus entitledONLYFRIENDS:\nA SMART PLATFORM FOR CONNECTING LIKE-MINDED INDIVIDUALSis\nour own work and has not been previously submitted by me at any university for any\nacademic award. We authorize Institute of Engineering, Purwanchal Campus to lend\nthis report to other institution or individuals for the purpose of scholarly research.\nAnish Dahal [PUR078BCT007]\nAmrit Gnawali [PUR078BCT006]\nKaushalendra Mahato [PUR078BCT042]\nKapildev Kumar Mahato [PUR078BCT041]\nMarch, 2025\nii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 3, 'page_label': '4', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='CERTIFICATE OF APPROV AL\nThe undersigned certify that they have read, and recommended to the Institute of\nEngineering for acceptance, a project report entitled ONLYFRIENDS: A SMART\nPLATFORM FOR CONNECTING LIKE-MINDED INDIVIDUALSsubmitted by\nAnish Dahal, Kaushalendra Mahato, Amrit Gnawali and Kapildev Kumar Mahato in\npartial fulfilment of the requirements for the Bachelor’s Degree in Computer Engineer-\ning.\nDeputy Head of Department: Asst. Prof. Pukar Karki\nDepartment of Electronics and Computer Engineering\nInstitute of Engineering, Purwanchal Campus\nDate of Approval: March, 2025\nSupervisor of Project: Asst. Prof. Bishnu Chaudhary\nDepartment of Electronics and Computer Engineering\nInstitute of Engineering, Purwanchal Campus\nDate of Approval: March, 2025\niii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 4, 'page_label': '5', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='ACKNOWLEDGEMENT\nWe express our sincere appreciation to our Suvervisor Asst. Prof. Bishnu Chaud-\nhary, Mr. Pukar Karki - the Deputy Head of the Department, for their invaluable guid-\nance, insightful suggestions, constructive feedback, and continuous support throughout\nthe preparation of this report.\nWe are deeply thankful to the esteemed teachers and faculty members whose valu-\nable feedback, encouragement, and scholarly insights have enriched this report. Their\ndedication to academic excellence and commitment to fostering knowledge have been\na source of inspiration. Their collective guidance has immensely contributed to the\nrefinement and improvement of this report.\nAMRIT GNAW ALI(PUR078 BCT006)\nANISH DAHAL(PUR078 BCT007)\nKAPIL DEV KUMAR MAHATO(PUR078 BCT041)\nKAUSHALENDRA MAHATO(PUR078 BCT042)\niv'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 5, 'page_label': '6', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='ABSTRACT\nThis is a web-based application designed to connect like-minded individuals by\nanalyzing user interests and suggesting potential connections. The platform enables\nusers to discover and engage with people who share similar interests. Users can review\nsuggested connections, send friend requests, and establish meaningful friendships.\nBeyond just making connections, the application provides an interactive chat feature\nthat allows users to engage in conversations with their matched contacts. Additionally,\nusers can create posts in text format to share their thoughts, updates, or ideas with\ntheir friends. Other users can interact by liking these posts, fostering engagement and\ndiscussions within the platform.\nThe primary objective of this project is to help individuals find companionship based\non shared interests, making it easier for them to connect, communicate, and establish\ngenuine relationships. This application is particularly designed for youths who are'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 5, 'page_label': '6', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='on shared interests, making it easier for them to connect, communicate, and establish\ngenuine relationships. This application is particularly designed for youths who are\nlooking for a fun, engaging, and easy-to-use platform to meet new people. The app\nserves as a tool for social networking and entertainment, allowing users to interact in a\ncomfortable virtual environment where they can vibe, have fun, and form meaningful\nconnections.\nKeywords: Social Networking, Interest-based friends Suggestion, Web-based Ap-\nplication, Cosine Similarity algorithm, Post and Like System, Entertainment-purpose,\nPost and Like system, Profile management, Real-time chat\nv'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 6, 'page_label': '7', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='TABLE OF CONTENTS\nCOPYRIGHT i\nDECLARATION ii\nCERTIFICATE OF APPROV AL iii\nACKNOWLEDGEMENT iv\nABSTRACT v\nLIST OF FIGURES ix\n0.1 JWT token implementation . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.2 cosine Vector visualization . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.3 System architecture diagram . . . . . . . . . . . . . . . . . . . . . . . ix\n0.4 Agile Model . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.5 System Use case diagram . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.6 System E-R diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.7 Class Diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.8 Dashboard . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.9 Suggestion Page . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\n0.10 Chat Page . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\nLIST OF ABBREVIATIONS x\n1 INTRODUCTION 1\nINTRODUCTION 1'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 6, 'page_label': '7', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='0.10 Chat Page . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ix\nLIST OF ABBREVIATIONS x\n1 INTRODUCTION 1\nINTRODUCTION 1\n1.1 Background . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1\n1.2 Problem Statement . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1\n1.3 Main Objectives . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1\n1.4 Scope and Application . . . . . . . . . . . . . . . . . . . . . . . . . . 2\n1.5 Feasibility analysis . . . . . . . . . . . . . . . . . . . . . . . . . . . . 2\n1.5.1 Technical Feasibility . . . . . . . . . . . . . . . . . . . . . . . 2\nvi'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 7, 'page_label': '8', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='1.5.2 Economic Feasibility . . . . . . . . . . . . . . . . . . . . . . . 3\n1.6 Performance Scalability . . . . . . . . . . . . . . . . . . . . . . . . . 3\n1.6.1 Performance: . . . . . . . . . . . . . . . . . . . . . . . . . . . 3\n1.6.2 Scalibility: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 4\n2 RELATED THEORY 5\nRELATED THEORY 5\n2.1 Introduction . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 5\n2.2 Social Networking Concepts . . . . . . . . . . . . . . . . . . . . . . . 5\n2.3 Web Development Technologies . . . . . . . . . . . . . . . . . . . . . 5\n2.4 Frontend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 5\n2.4.1 React (Frontend Framework) . . . . . . . . . . . . . . . . . . . 5\n2.5 Backend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 6\n2.5.1 FastAPI (Backend Framework) . . . . . . . . . . . . . . . . . . 6\n2.6 User Authentication and Security . . . . . . . . . . . . . . . . . . . . . 6'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 7, 'page_label': '8', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='2.5.1 FastAPI (Backend Framework) . . . . . . . . . . . . . . . . . . 6\n2.6 User Authentication and Security . . . . . . . . . . . . . . . . . . . . . 6\n2.6.1 JWT . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 6\n2.7 Chat Functionality . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7\n2.8 Recommendation System . . . . . . . . . . . . . . . . . . . . . . . . . 7\n2.9 Cosine Similarity . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 8\n3 Literature Review 10\nLITERATURE REVIEW 10\n3.1 FastAPI and Modern Web Frameworks . . . . . . . . . . . . . . . . . . 10\n3.2 SQLAlchemy for Database Management . . . . . . . . . . . . . . . . . 10\n3.3 React + Vite for Frontend Development . . . . . . . . . . . . . . . . . 10\n3.4 Firebase for Real-Time Communication . . . . . . . . . . . . . . . . . 10\n3.5 Cosine Similarity and Interest Matching . . . . . . . . . . . . . . . . . 11\n4 METHODOLOGY 12\nvii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 8, 'page_label': '9', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='METHODOLOGY 12\n4.1 Overview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.2 Requirements Analysis . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.3 System Design . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.4 Frontend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 12\n4.5 Backend Development . . . . . . . . . . . . . . . . . . . . . . . . . . 13\n4.6 Implementing Real-time chat . . . . . . . . . . . . . . . . . . . . . . . 13\n4.7 Profile Matching . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13\n4.8 Software Development Model . . . . . . . . . . . . . . . . . . . . . . 14\n5 UML Diagrams 16\n5.1 System Use Case Diagram . . . . . . . . . . . . . . . . . . . . . . . . 17\n5.2 Entity-Relationship (E-R) diagram . . . . . . . . . . . . . . . . . . . . 18\n5.3 Class diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 19\n6 RESULT AND DISCUSSION 20\nRESULT AND DISCUSSION 20'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 8, 'page_label': '9', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='5.3 Class diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 19\n6 RESULT AND DISCUSSION 20\nRESULT AND DISCUSSION 20\n6.1 Result: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 20\n7 CONCLUSION AND LIMITATION 22\nCONCLUSION AND LIMITATION 22\n7.1 Conclusion: . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 22\n7.2 Limitations . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 22\nREFERENCES 24\nviii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 9, 'page_label': '10', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='List of Figures\n0.1 JWT token implementation\n0.2 cosine Vector visualization\n0.3 System architecture diagram\n0.4 Agile Model\n0.5 System Use case diagram\n0.6 System E-R diagram\n0.7 Class Diagram\n0.8 Dashboard\n0.9 Suggestion Page\n0.10 Chat Page\nix'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 10, 'page_label': '11', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='LIST OF ABBREVIATIONS\nAPI : Application Programming Interface\nAWS : Amazon Web Service\nColab : Colaboratory\nJWT : JSON Web Token\nJSON : Javascript Object Notation\nNLP : Natural Language Processing\nOAuth2 : Open Authorization 2.0\nSPA : single Page Application\nUI : User Interface\nx'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 11, 'page_label': '12', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='CHAPTER 1\nINTRODUCTION\n1.1 Background\nIn today’s digital age, social connectivity has become a significant aspect of every-\nday life. However, traditional social media platforms often focus on broad connections,\nleaving a gap for users seeking meaningful interactions with like-minded individuals.\nRecognizing this need, OnlyFriend is designed as a web-based application to bridge this\ngap. It aims to create an interactive environment where users can register, manage their\nprofiles, and connect with others based on their common interests. Unlike conventional\nsocial media, OnlyFriends emphasizes meaningful conversations and topic-based inter-\nactions. It integrates essential features such as real-time chat, user authentication, and\nprofile management to ensure a seamless and user-friendly experience. The platform\naspires to serve as a hub for entertainment and engagement, particularly for the youth,\nfostering friendships that transcend geographical boundaries.\n1.2 Problem Statement'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 11, 'page_label': '12', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='aspires to serve as a hub for entertainment and engagement, particularly for the youth,\nfostering friendships that transcend geographical boundaries.\n1.2 Problem Statement\nCurrent social media platforms prioritize network expansion over fostering mean-\ningful connections, often resulting in superficial interactions. Users find it difficult\nto connect with like-minded individuals due to the absence of an efficient interest-\nbased matching system. Additionally, many platforms have complex interfaces and\noverwhelming features, making it hard for users to focus on building genuine relation-\nships. OnlyFriends aims to bridge this gap by providing a user-friendly, interest-driven\nsocial platform where users can easily discover and connect with individuals who share\nsimilar hobbies. By integrating features like profile matching, real-time chat, and user-\ngenerated content (posts likes), the platform enhances engagement and encourages au-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 11, 'page_label': '12', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='similar hobbies. By integrating features like profile matching, real-time chat, and user-\ngenerated content (posts likes), the platform enhances engagement and encourages au-\nthentic social interactions, making online friendships more meaningful and enjoyable\n1.3 Main Objectives\n1. To develop a platform that connects users based on shared interests and hobbies,\nfostering meaningful virtual friendships.\n2. To provide features like real-time chat, content posting, and liking posts to en-\ncourage engagement.\n3. To design an intuitive and accessible interface for seamless navigation and inter-\naction.\n1'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 12, 'page_label': '13', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='1.4 Scope and Application\nThe scope and application of this project are as follows:\n• User Registration and Profile Management: The platform allows users to cre-\nate, update, and manage their profiles, ensuring personalized interactions.\n• Interest-Based Matching: Users are connected based on shared interests facili-\ntating meaningful interactions and friendships.\n• Real-Time Communication: The application integrates real-time chat function-\nality to facilitate communication between connected users.\n• User-Friendly Interface: The platform ensures an intuitive, easy-to-use inter-\nface, making it accessible to a wide range of users, especially the youth.\n• Security and Privacy: The platform guarantees data security and user privacy,\nensuring safe interactions and profile management.\n1.5 Feasibility analysis\nConducting a feasibility analysis is a critical step in assessing the viability of project,\nwherein the potential success is evaluated through an examination of economic, tech-'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 12, 'page_label': '13', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='Conducting a feasibility analysis is a critical step in assessing the viability of project,\nwherein the potential success is evaluated through an examination of economic, tech-\nnical, and operational factors. In this particular analysis, we will assess the feasibility\nof creating ONLYFRIENDS: A SMART PLATFORM FOR CONNECTING LIKE-\nMINDED INDIVIDUALS\n1.5.1 Technical Feasibility\nThe technical feasibility of the **OnlyFriends** platform is achievable through the\nintegration of several key technologies:\n• The platform is built using modern web technologies like React for the frontend\nand Python based framework FastAPI for the backend, ensuring smooth com-\nmunication and responsiveness.\n• PostgreSQL has been utilized for user data storage, ensuring scalability, data\nintegrity, and secure user information management.\n• Firebase is implemented to ensure real-time communication between users, al-\nlowing them to interact instantly.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 12, 'page_label': '13', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='integrity, and secure user information management.\n• Firebase is implemented to ensure real-time communication between users, al-\nlowing them to interact instantly.\n• Secure user authentication will be implemented through JWT (JSON Web To-\nkens), ensuring secure login and data protection.\n• The platform has used the Cosine Similarity algorithm to match users based\n2'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 13, 'page_label': '14', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='on their shared interests. By calculating the similarity between users’ profiles\n(which include interests, the system will suggest users with the most similar in-\nterests(greater than 10 percent), enhancing the likelihood of meaningful connec-\ntions.\n• The platform has been designed with scalability in mind, ensuring that it can\nhandle increasing numbers of users without compromising performance.\n1.5.2 Economic Feasibility\nThe economic feasibility of the **OnlyFriends** platform evaluates the costs, fi-\nnancial benefits, and overall viability of the project. By analyzing initial investment,\noperational costs, and potential revenue sources, we assess the platform’s sustainability\nand profitability.\n• Initial Investment: Development costs include web development tools, devel-\noper hiring, and infrastructure setup, which can be minimized by using open-\nsource technologies like React, FastAPI, and PostgreSQL.\n• Operational Costs: Ongoing expenses include server hosting, maintenance, and'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 13, 'page_label': '14', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='source technologies like React, FastAPI, and PostgreSQL.\n• Operational Costs: Ongoing expenses include server hosting, maintenance, and\ndata storage. Cloud services like AWS and Firebase offer cost-effective solutions\nto scale the platform.\n• Revenue Streams: The platform can generate revenue through:\n– Premium Memberships: Offering additional features for a subscription\nfee.\n– Advertisements: Generating revenue through non-intrusive ads.\n• Market Demand: With growing demand for personalized online interactions,\nthe platform can tap into an underserved market, particularly among youth and\nhobbyists.\n• Long-Term Sustainability: The low cost of cloud-based services, combined\nwith recurring revenue from premium memberships and in-app purchases, en-\nsures the platform’s long-term economic viability.\n1.6 Performance Scalability\n1.6.1 Performance:\nThe OnlyFriends platform is optimized for high performance, ensuring seamless'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 13, 'page_label': '14', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='sures the platform’s long-term economic viability.\n1.6 Performance Scalability\n1.6.1 Performance:\nThe OnlyFriends platform is optimized for high performance, ensuring seamless\nuser interactions and real-time communication. The backend, built using FastAPI,\n3'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 14, 'page_label': '15', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='leverages asynchronous processing to handle multiple requests efficiently. PostgreSQL\nensures fast query execution and optimized data retrieval, while Firebase enables low-\nlatency real-time chat. For interest-based profile matching, the Cosine Similarity algo-\nrithm efficiently processes large datasets by representing user interests as vectors and\ncomputing similarity scores, ensuring quick and accurate user recommendations.\n1.6.2 Scalibility:\nThe OnlyFriends platform is designed with scalability in mind, ensuring that it can\nhandle a growing user base without performance degradation. The microservices-based\nbackend, developed with FastAPI, allows independent scaling of different components\nsuch as authentication, chat, and profile matching. PostgreSQL is optimized for large-\nscale data handling, while Firebase provides scalable real-time communication. The\nCosine Similarity algorithm is implemented efficiently to handle increasing data by'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-03-02T14:45:54+00:00', 'moddate': '2025-03-02T14:45:54+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'data\\pdfs\\Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'total_pages': 36, 'page': 14, 'page_label': '15', 'source_file': 'Minor_Project_Report_Formatting_20241218T145305Z_001__3_.pdf', 'file_type': 'pdf'}, page_content='scale data handling, while Firebase provides scalable real-time communication. The\nCosine Similarity algorithm is implemented efficiently to handle increasing data by\nusing vectorized computations and indexing techniques.\n4'),
# ...
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 24, 'page_label': '25', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='25 \n \nTable 1. Frequencies for qualitative data (N=149,557) \nVariables Categories Num articles % \nJournal expert rating A* (higher) 24,849 16.6  \nA 43,560 29.1  \nB 48,762 32.6  \nC (lower) 32,386 21.7 \nJournal best quartile SJR Q1 (higher) 119,718 80.0  \nQ2 22,387 15.0  \nQ3 6,046 4.0  \nQ4 (lower) 1,406 1.0 \nOA status No 92,262 61.7  \nYes 57,295 38.3 \nOA type closed 92,261 61.7 \n hybrid 20,938 14.0  \ngreen 22,202 14.8  \ngold 3,903 2.6  \nbronze 10,253 6.9 \nFunding No 117,764 78.7 \n Yes 31,793 21.3 \nPublication year 2014 12,565 8.4  \n2015 12,064 8.1  \n2016 20,959 14.0  \n2017 14,454 9.7  \n2018 14,236 9.5  \n2019 14,421 9.6  \n2020 15,870 10.6  \n2021 16,018 10.7  \n2022 15,146 10.1 \n  2023 13,824 9.2'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 25, 'page_label': '26', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='26 \n \nTable 2. Descriptive statistics for quantitative data (N=149,557) \nVariables Min Max Mean SD \nPolicy citations 0 119 0.209 1.142 \nJournal prestige score SJR 0.101 8.346 1.233 1.237 \nJournal impact (cites per doc 3 years) 0.053 15.297 3.168 2.331 \nNews mentions 0 386 0.545 3.858 \nBlog mentions 0 122 0.212 0.820 \nPatent citations 0 33 0.002 0.109 \nX mentions 0 16316 11.971 77.324 \nFacebook mentions 0 133 0.139 0.672 \nWikipedia mentions 0 47 0.156 0.840 \nVideo mentions 0 12 0.002 0.065 \nMendeley readers 0 9939 37.615 78.733 \nScientiﬁc citations 0 4669 18.333 58.373'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 26, 'page_label': '27', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='27 \n \nTable 3. ANOVA for log Policy citations \nSource Coef. Stand. \nerror t Pr > |t| \nLower \nlimit \n(95%) \nUpper \nlimit \n(95%) \np-\nvalues \ncodes \nInterception -0.029 0.004 -7.212 <0.0001 -0.036 -0.021 *** \nJournal expert rating-A* 0.034 0.001 27.066 <0.0001 0.032 0.037 *** \nJournal expert rating-A 0.013 0.001 11.289 <0.0001 0.010 0.015 *** \nJournal expert rating-B 0.004 0.001 3.442 0.001 0.002 0.006 *** \nJournal expert rating-C 0.000 0.000      \nJournal best quartile SJR-Q1 0.022 0.004 5.877 <0.0001 0.015 0.030 *** \nJournal best quartile SJR-Q2 0.016 0.004 4.241 <0.0001 0.009 0.024 *** \nJournal best quartile SJR-Q3 0.009 0.004 2.216 0.027 0.001 0.017 * \nJournal best quartile SJR-Q4 0.000 0.000      \nOA type-hybrid 0.040 0.001 34.992 <0.0001 0.038 0.043 *** \nOA type-green 0.018 0.001 17.041 <0.0001 0.016 0.020 *** \nOA type-gold 0.043 0.002 18.423 <0.0001 0.039 0.048 *** \nOA type-bronze 0.012 0.001 8.184 <0.0001 0.009 0.015 *** \nOA type-closed 0.000 0.000'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 26, 'page_label': '27', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='OA type-gold 0.043 0.002 18.423 <0.0001 0.039 0.048 *** \nOA type-bronze 0.012 0.001 8.184 <0.0001 0.009 0.015 *** \nOA type-closed 0.000 0.000      \nFunding-No -0.022 0.001 -24.512 <0.0001 -0.024 -0.021 *** \nFunding-Yes 0.000 0.000      \nPublication year-2014 0.083 0.002 47.309 <0.0001 0.080 0.087 *** \nPublication year-2015 0.072 0.002 40.585 <0.0001 0.068 0.075 *** \nPublication year-2016 0.077 0.002 48.751 <0.0001 0.073 0.080 *** \nPublication year-2017 0.064 0.002 38.108 <0.0001 0.061 0.068 *** \nPublication year-2018 0.060 0.002 35.629 <0.0001 0.057 0.064 *** \nPublication year-2019 0.047 0.002 28.271 <0.0001 0.044 0.051 *** \nPublication year-2020 0.037 0.002 22.607 <0.0001 0.034 0.040 *** \nPublication year-2021 0.026 0.002 15.931 <0.0001 0.023 0.029 *** \nPublication year-2022 0.012 0.002 7.332 <0.0001 0.009 0.015 *** \nPublication year-2023 0.000 0.000      \nSigniﬁcation codes: *** very highly signiﬁcant; ** highly signiﬁcant; * signiﬁcant; 0 < *** < 0.001 \n< ** < 0.01 < * < 0.05'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 27, 'page_label': '28', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='28 \n \nTable 4. Correlations \n  \nJournal prestige score \nSJR \nJournal impact (cites \nper doc 3 years) \nArticle age (years) \nlog News mentions \nlog Blog mentions \nlog Patent citations \nlog X mentions \nlog Facebook \nmentions \nlog Wikipedia \nmentions \nlog Video mentions \nlog Mendeley readers \nlog Scientific citations \nlog Policy citations \nJournal prestige score SJR 1 0.77 0.08 0.10 0.18 0.02 0.15 0.00 0.09 0.01 0.23 0.27 0.14 \nJournal impact (cites per doc 3 years) 0.77 1 0.02 0.09 0.17 0.02 0.13 0.00 0.02 0.02 0.41 0.36 0.20 \nArticle age (years) 0.08 0.02 1 0.01 0.02 0.01 -0.29 0.13 0.09 0.00 0.30 0.39 0.15 \nlog News mentions 0.10 0.09 0.01 1 0.38 0.01 0.24 0.09 0.13 0.09 0.20 0.23 0.15 \nlog Blog mentions 0.18 0.17 0.02 0.38 1 0.01 0.24 0.10 0.10 0.08 0.22 0.25 0.16 \nlog Patent citations 0.02 0.02 0.01 0.01 0.01 1 -0.01 0.00 0.00 0.01 0.02 0.02 0.03 \nlog X mentions 0.15 0.13 -0.29 0.24 0.24 -0.01 1 0.14 0.04 0.05 0.20 0.16 0.05'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 27, 'page_label': '28', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='log Patent citations 0.02 0.02 0.01 0.01 0.01 1 -0.01 0.00 0.00 0.01 0.02 0.02 0.03 \nlog X mentions 0.15 0.13 -0.29 0.24 0.24 -0.01 1 0.14 0.04 0.05 0.20 0.16 0.05 \nlog Facebook mentions 0.00 0.00 0.13 0.09 0.10 0.00 0.14 1 0.03 0.04 0.10 0.11 0.06 \nlog Wikipedia mentions 0.09 0.02 0.09 0.13 0.10 0.00 0.04 0.03 1 0.04 0.07 0.12 0.06 \nlog Video mentions 0.01 0.02 0.00 0.09 0.08 0.01 0.05 0.04 0.04 1 0.04 0.04 0.03 \nlog Mendeley readers 0.23 0.41 0.30 0.20 0.22 0.02 0.20 0.10 0.07 0.04 1 0.81 0.34 \nlog Scientific citations 0.27 0.36 0.39 0.23 0.25 0.02 0.16 0.11 0.12 0.04 0.81 1 0.37 \nlog Policy citations 0.14 0.20 0.15 0.15 0.16 0.03 0.05 0.06 0.06 0.03 0.34 0.37 1 \nNote: The log refers to the natural logarithm in base e of the variable shifted by one unit.'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 28, 'page_label': '29', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='29 \n \nTable 5. Analysis of variance (log Policy citations) \nSource GL Sum of \nsquares \nSum of \nsquares \nF Pr > F \nModel  19 475.868 25.046 1471.214 <0.0001 \nError 149537 2545.692 0.017 \n  \nTotal corrected 149556 3021.561 \n   \nNote: Calculated against the model Y=Mean(Y). Adjusted R² = 0.157.'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 29, 'page_label': '30', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='30 \n \nTable 6. Model parameters (log Policy citations) \nSource Coef. Stand. \nerror t Pr > |t| \nLower \nlimit \n(95%) \nUpper \nlimit \n(95%) \np-\nvalues \ncodes \nStand. \ncoef. \nJournal level metrics         \nJournal expert rating (higher better) -0.002 0.000 -4.387 <0.0001 -0.003 -0.001 *** -0.014 \nJournal prestige score SJR -0.002 0.000 -4.252 <0.0001 -0.003 -0.001 *** -0.018 \nJournal best quartile SJR (top better) -0.007 0.001 -10.706 <0.0001 -0.008 -0.006 *** -0.028 \nJournal impact score (cites per doc 3 years) 0.005 0.000 20.452 <0.0001 0.005 0.006 *** 0.089 \nArticle attributes         \nArticle age (years) 0.001 0.000 9.555 <0.0001 0.001 0.002 *** 0.029 \nFunding (Yes=1, No=0) 0.002 0.001 2.057 0.040 0.000 0.004 * 0.005 \nOA (relative to closed)         \n     OA hybrid 0.020 0.001 18.155 <0.0001 0.018 0.022 *** 0.049 \n     OA green 0.001 0.001 1.115 0.265 -0.001 0.003 ° 0.003 \n     OA gold 0.011 0.002 4.863 <0.0001 0.006 0.015 *** 0.012'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 29, 'page_label': '30', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='OA hybrid 0.020 0.001 18.155 <0.0001 0.018 0.022 *** 0.049 \n     OA green 0.001 0.001 1.115 0.265 -0.001 0.003 ° 0.003 \n     OA gold 0.011 0.002 4.863 <0.0001 0.006 0.015 *** 0.012 \n     OA bronze 0.006 0.001 4.623 <0.0001 0.004 0.009 *** 0.011 \nArticle level metrics         \nlog News mentions 0.038 0.002 21.625 <0.0001 0.034 0.041 *** 0.057 \nlog Blog mentions 0.055 0.003 20.321 <0.0001 0.050 0.061 *** 0.054 \nlog Patent citations 0.227 0.025 9.196 <0.0001 0.179 0.275 *** 0.022 \nlog X mentions -0.010 0.001 -14.248 <0.0001 -0.012 -0.009 *** -0.040 \nlog Facebook mentions 0.012 0.003 3.865 <0.0000 0.006 0.018 *** 0.009 \nlog Wikipedia mentions 0.008 0.003 2.791 0.005 0.002 0.013 ** 0.007 \nlog Video mentions 0.036 0.022 1.641 0.101 -0.007 0.079 ° 0.004 \nlog Mendeley readers 0.020 0.001 19.412 <0.0001 0.018 0.022 *** 0.086 \nlog Scientific citations 0.057 0.001 56.597 <0.0001 0.055 0.059 *** 0.247 \nInterception -0.058 0.002 -32.023 <0.0001 -0.062 -0.055 *** -'),
#  Document(metadata={'producer': 'Adobe PDF Library 25.1.211', 'creator': 'Acrobat PDFMaker 25 para Word', 'creationdate': '2025-04-26T11:39:38+01:00', 'author': 'Pablo Dorta González', 'comments': '', 'company': '', 'contenttypeid': '0x01010042865B7B0B1AB8408FFEF7A3320319F8', 'grammarlydocumentid': 'fa88d9ca86a0719b32858336dd43a2037aa3eea3ea63209f9af674c40b61f0b9', 'keywords': '', 'moddate': '2025-04-26T11:39:52+01:00', 'sourcemodified': 'D:20250426103621', 'subject': '', 'title': '', 'source': 'data\\pdfs\\Which_kind_of_research_papers_influence_policymaki.pdf', 'total_pages': 30, 'page': 29, 'page_label': '30', 'source_file': 'Which_kind_of_research_papers_influence_policymaki.pdf', 'file_type': 'pdf'}, page_content='log Scientific citations 0.057 0.001 56.597 <0.0001 0.055 0.059 *** 0.247 \nInterception -0.058 0.002 -32.023 <0.0001 -0.062 -0.055 *** - \nSigniﬁcation codes: *** very highly signiﬁcant; ** highly signiﬁcant; * signiﬁcant; . marginally \nsigniﬁcant; ° not signiﬁcant; 0 < *** < 0.001 < ** < 0.01 < * < 0.05 < . < 0.1 < ° < 1. The log refers \nto the natural logarithm in base e of the variable shifted by one unit.')]

# %% [markdown]
# ### Embeding and VectorStoreDB

# %%
# !pip install sentence-transformers
# !pip install chromadb
# !pip install faiss-cpu

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Tuple, Dict, Any
from sklearn.metrics.pairwise import cosine_similarity

# %%
class EmbeddingManager:
    def __init__(self, model_name: str = "all-MiniLM-L6-V2"):
        """Initialize the embedding manager"""
        self.model_name = model_name
        self.model = None
        self._load_model()
    
    def _load_model(self):
        """Load the sentence transformer model"""
        try:
            print(f"Loading the model {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model successfully loaded. Embedding dimension: {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"Error loading model {self.model_name}: {e}")
            raise

    def generate_embeddings(self, texts: List[str]) -> np.ndarray:
        """Generate a embedding for a list of text
            Args: texts: List of text strings to embed
            returns: numpy array of embeddings with shape (len(texts), embedding_dim)
        """
        if not self.model:
            raise ValueError("Model not loaded!")
        print(f"Generating embeddings for {len(texts)} texts.")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print(f"Generated embeddings with shape: {embeddings.shape}")
        return embeddings


## initialize the embedding manager

embedding_manager = EmbeddingManager()
embedding_manager
# Out:
# Loading the model all-MiniLM-L6-V2
# Model successfully loaded. Embedding dimension: 384
